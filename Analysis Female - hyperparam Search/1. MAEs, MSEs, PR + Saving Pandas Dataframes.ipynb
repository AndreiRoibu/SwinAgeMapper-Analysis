# %%
import os
import pickle
from glob import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from scipy.stats import pearsonr

# %%
def age_debiasing(predicted_ages, chronological_ages):
    
    predicted_ages = predicted_ages.to_numpy()
    chronological_ages = chronological_ages.to_numpy()
    
    ones = np.ones(len(chronological_ages))
    chronological_ages_squared = np.square(chronological_ages)
    chronological_ages_confounds = np.array([ones, chronological_ages])
    
    ones_predicted = np.ones(len(predicted_ages))
    predicted_ages_squared = np.square(predicted_ages)
    predicted_ages_confounds = np.array([ones_predicted, predicted_ages])
    
    predicted_ages = np.reshape(predicted_ages, (len(predicted_ages), 1) )
    beta = np.dot( np.linalg.pinv(chronological_ages_confounds.T), predicted_ages )

    corrected_predicted_ages = (predicted_ages.flatten() - beta[0])/beta[1]
    
    return corrected_predicted_ages

# %%
# net1 = "0"
net2 = "3"
net3 = "4"
net4 = "5"
net5 = "6"
net6 = "7"
net7 = "8"
net8 = '9'
net9 = '10'
net10 = '11'
net11 = "12"
net12 = "13"
net13 = "14"
net14 = "17"
net15 = "18"
net16 = "19"
net17 = "20"
net18 = "21"
net19 = "22"
net20 = "23"
net21 = "24"
###############
net25 = '25'
net26 = '26'
net27 = '27'
net28 = '28'
net29 = '29'
net30 = '30'

net49 = '49'
net50 = '50'
net51 = '51'
net52 = '52'
net53 = '53'
net54 = '54'

net52b = '52b'
net53b = '53b'
net54b = '54b'

net82 = '82'
net83 = '83'
net84 = '84'
net85 = '85'
net86 = '86'
net87 = '87'
net88 = '88'
net89 = '89'
net90 = '90'
net91 = '91'
net92 = '92'
net93 = '93'
net94 = '94'
net95 = '95'
net96 = '96'
net97 = '97'
net98 = '98'
net99 = '99'
net100 = '100'
net101 = '101'

dfs = [
#     net1,
    net2,
    net3,
    net4,
    net5,
    net6,
    net7,
    net8,
    net9,
    net10,
    net11,
    net12,
    net13,
    net14,
    net15,
    net16,
    net17,
    net18,
    net19,
    net20,
    net21,
    ############
    net25,
    net26,
    net27,
    net28,
    net29,
    net30,
    net49,
    net50,
    net51,
    net52,
    net53,
    net54,
    net52b,
    net53b,
    net54b,
    ############
    net82,
    net87,
    net92,
    net97,
    
    net83,
    net88,
    net93,
    net98,
    
    net84,
    net89,
    net94,
    net99,
    
    net85,
    net90,
    net95,
    net100,
    
    net86,
    net91,
    net96,
    net101,
]

names = [
#     '3k_original', # 1
    '3k_baseline', # 2
    'depth=(1,1,1,1)', # 3
    'heads=(2,4,8,16),b=4', # 4
    'feature_size=3', # 5
    'feature_size=6', # 6
    'feature_size=12', # 7
    'patch_size=3', #8
    'patch_size=4', #9
    'patch_size=5', #10
    'warmup=0', # 11
    'warmup=8', # 12
    'warmup=12', # 13
    'weight_decay=1e-2', # 14
    'weight_decay=1e-3', # 15
    'weight_decay=1e-4', # 16
    'weight_decay=0', # 17
    'cosine_sch = 60', # 18
    'cosine_sch = 120', # 19
    'cosine_sch = 200', # 20
    'no_random_shift', # 21
    #####################
    'patch=5,feature=48', #25
    'patch=5,feature=72', #26
    'patch=5,feature=96', #27
    'patch=5,feature=48,patience=30,lr=5e-3,200epc', #28
    'patch=5,feature=72,patience=30,lr=5e-3,200epc', #29
    'patch=5,feature=96,patience=30,lr=5e-3,200epc', #30
    'patch=5,feature=48,patience=40,200epc', #49
    'patch=5,feature=72,patience=40,200epc', #50
    'patch=5,feature=96,patience=40,200epc', #51
    'patch=5,feature=48,patience=40,step_lr,200epc', #52
    'patch=5,feature=72,patience=40,step_lr,200epc', #53
    'patch=5,feature=96,patience=40,step_lr,200epc', #54
    'patch=5,feature=48,patience=40,step_lr,120epc', #52b
    'patch=5,feature=72,patience=40,step_lr,120epc', #53b
    'patch=5,feature=96,patience=40,step_lr,120epc', #54b
    ############
    'T1NL, p5, f24, d=(2,2,2,2)',#net82
    'T1NL, p5, f48, d=(2,2,2,2)',#net87
    'T1NL, p5, f24, d=(2,2,2)',#net92    
    'T1NL, p5, f24, d=(2,2,2)',#net97    
    
    'FA, p5, f24, d=(2,2,2,2)',#net83
    'FA, p5, f48, d=(2,2,2,2)',#net88    
    'FA, p5, f24, d=(2,2,2)',#net93
    'FA, p5, f48, d=(2,2,2)',#net98
    
    'TBSS FA, p5, f24, d=(2,2,2,2)',#net84
    'TBSS FA, p5, f48, d=(2,2,2,2)',#net89    
    'TBSS FA, p5, f24, d=(2,2,2)',#net94    
    'TBSS FA, p5, f48, d=(2,2,2)',#net99    
    
    'rsfMRI, p5, f24, d=(2,2,2,2)',#net85
    'rsfMRI, p5, f48, d=(2,2,2,2)',#net90    
    'rsfMRI, p5, f24, d=(2,2,2)',#net95
    'rsfMRI, p5, f48, d=(2,2,2)',#net100    
    
    'tracts, p5, f24, d=(2,2,2,2)',#net86
    'tracts, p5, f48, d=(2,2,2,2)',#net91
    'tracts, p5, f24, d=(2,2,2)',#net96
    'tracts, p5, f48, d=(2,2,2)',#net101
]


dfs1, dfs2, dfs3 = [], [], []

dfs1 = dfs.copy()
dfs2 = dfs.copy()
dfs3 = dfs.copy()

for idx in range(len(dfs)):
    
#     if idx == 1:
#         dfs1[idx] = '../predictions/SM1-' + dfs1[idx] + '_predictions/output_statistics_test.csv'
#     else:
    dfs1[idx] = '../predictions/SM0-' + dfs1[idx] + '_predictions/output_statistics_test.csv'
    dfs2[idx] = '../predictions/SM1-' + dfs2[idx] + '_predictions/output_statistics_test.csv'
    dfs3[idx] = '../predictions/SM2-' + dfs3[idx] + '_predictions/output_statistics_test.csv'
    
for idx in range(len(dfs)):
    dfs1[idx] = pd.read_csv(dfs1[idx])
    dfs2[idx] = pd.read_csv(dfs2[idx])
    dfs3[idx] = pd.read_csv(dfs3[idx])

# %%
dfs = dfs1

# %%
dfs[0]
# Out:
#      Unnamed: 0  target_age  output_age  age_delta        loss
# 0      24642634   68.817620   71.761314   2.943695    8.665340
# 1      25438579   54.541897   53.974083  -0.567814    0.322413
# 2      21026392   67.284820   63.286260  -3.998562   15.988497
# 3      22526044   67.492805   68.328830   0.836021    0.698932
# 4      25008425   53.802400   65.822860  12.020462  144.491500
# ..          ...         ...         ...        ...         ...
# 994    22396579   53.442810   53.374626  -0.068184    0.004649
# 995    21351411   52.529110   53.400100   0.870991    0.758625
# 996    21230487   53.252050   54.929770   1.677723    2.814754
# 997    22579199   64.787560   65.337270   0.549713    0.302185
# 998    24735119   70.165985   65.012070  -5.153915   26.562843
#
# [999 rows x 5 columns]

# %%
for idx in range(len(dfs)):
    dfs[idx] = pd.merge(dfs1[idx], dfs2[idx], on='Unnamed: 0', how='inner')
    dfs[idx] = pd.merge(dfs[idx], dfs3[idx], on='Unnamed: 0', how='inner')
    
    dfs[idx].rename({
        'target_age_x': 'target_age_original',
        'output_age_x': 'output_age_1',
        'age_delta_x': 'age_delta_1',
        'loss_x': 'loss_1',
        'target_age_y': 'target_age_2',
        'output_age_y': 'output_age_2',
        'age_delta_y': 'age_delta_2',
        'loss_y': 'loss_2',
        'target_age': 'target_age_3',
        'output_age': 'output_age_3',
        'age_delta': 'age_delta_3',
        'loss': 'loss_3',
    }, axis=1, inplace=True)
    
    dfs[idx].drop(['target_age_2', 'target_age_3'], axis=1, inplace=True)
    
    dfs[idx].rename({
        'target_age_original': 'target_age',
    }, axis=1, inplace=True)
    
    dfs[idx]['mean_output_age'] = dfs[idx][['output_age_1', 'output_age_2', 'output_age_3']].mean(axis=1)
    dfs[idx]['mean_age_delta'] = dfs[idx]['mean_output_age'] - dfs[idx]['target_age']

# %%
for idx in range(len(dfs)):    
    dfs[idx]['output_age_decon'] = age_debiasing(dfs[idx].mean_output_age, dfs[idx].target_age) 
    dfs[idx]['age_delta_decon'] = dfs[idx].output_age_decon - dfs[idx].target_age

# for idx in range(len(dfs)):    
#     dfs[idx]['output_age_decon'] = age_debiasing(dfs[idx].output_age, dfs[idx].target_age) 
#     dfs[idx]['age_delta_decon'] = dfs[idx].output_age_decon - dfs[idx].target_age

# %%
# print("{:13} : {:14}  |  {:13}  ".format('Modality', 'MEAN (MAE)', "MEAN DECONF"))
# print('-----------------------------------------------------------------------------------------------')

# for idx in range(len(dfs)):
#     print("{:13} :  {:.3f} ± {:.3f}  |   {:.3f} ± {:.3f} ".format(
#         names[idx],
#         np.abs(dfs[idx].mean_age_delta).mean(), np.abs(dfs[idx].mean_age_delta).std()/np.sqrt(len(dfs[idx])),
#         np.abs(dfs[idx].age_delta_decon).mean(), np.abs(dfs[idx].age_delta_decon).std()/np.sqrt(len(dfs[idx])),
#     )
#          )

print("{:23} : {:7}  |  {:13}  ".format('Modality', 'MEAN (MAE)', "MEAN DECONF"))
print('-----------------------------------------------------------------------------------------------')

for idx in range(len(dfs)):
    print("{:23} :  {:.3f}  |   {:.3f}  ".format(
        names[idx],
        np.abs(dfs[idx].age_delta).mean(), #np.abs(dfs[idx].age_delta).std()/np.sqrt(len(dfs[idx])),
        np.abs(dfs[idx].age_delta_decon).mean(), # np.abs(dfs[idx].age_delta_decon).std()/np.sqrt(len(dfs[idx])),
    )
         )
    
# T1 NonLinear:    2.858 | 2.994
# T2 NonLinear:    2.707 | 3.297
# Out:
# Modality                : MEAN (MAE)  |  MEAN DECONF
# -----------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-b69a03acb77b> in <module>
#      16     print("{:23} :  {:.3f}  |   {:.3f}  ".format(
#      17         names[idx],
# ---> 18         np.abs(dfs[idx].age_delta).mean(), #np.abs(dfs[idx].age_delta).std()/np.sqrt(len(dfs[idx])),
#      19         np.abs(dfs[idx].age_delta_decon).mean(), # np.abs(dfs[idx].age_delta_decon).std()/np.sqrt(len(dfs[idx])),
#      20     )
#
# ~/agemapper/env/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'age_delta'

# %%
print("{:30} : {:7}  |  {:7}  |  {:7}  |  {:7}".format('Modality', 'Run1', "Run2", "Run3", "MAE"))
print('-----------------------------------------------------------------------------------------------')

for idx in range(len(dfs)):
    print("{:30} : {:7.3f} |  {:7.3f}  |  {:7.3f} | {:7.3f}".format(
        names[idx],
        np.abs(dfs[idx].age_delta_1).mean(), 
        np.abs(dfs[idx].age_delta_2).mean(),
        np.abs(dfs[idx].age_delta_3).mean(), 
        np.abs(dfs[idx].mean_age_delta).mean(), 
    )
         )
# Out:
# Modality                       : Run1     |  Run2     |  Run3     |  MAE
# -----------------------------------------------------------------------------------------------
# 3k_baseline                    :   2.998 |    2.931  |    2.928 |   2.828
# depth=(1,1,1,1)                :   2.890 |    2.939  |    2.983 |   2.818
# heads=(2,4,8,16),b=4           :   2.951 |    3.096  |    3.072 |   2.901
# feature_size=3                 :   3.055 |    2.974  |    3.432 |   2.829
# feature_size=6                 :   3.097 |    3.145  |    3.034 |   2.887
# feature_size=12                :   2.927 |    3.098  |    2.934 |   2.842
# patch_size=3                   :   3.034 |    3.074  |    3.314 |   2.938
# patch_size=4                   :   3.063 |    3.117  |    3.053 |   2.916
# patch_size=5                   :   3.012 |    3.006  |    3.105 |   2.847
# warmup=0                       :  63.414 |   63.559  |   63.287 |  63.420
# warmup=8                       :   2.918 |    2.982  |    3.050 |   2.830
# warmup=12                      :   2.973 |    3.085  |    3.018 |   2.866
# weight_decay=1e-2              :   2.995 |    3.026  |    3.002 |   2.891
# weight_decay=1e-3              :   3.024 |    6.248  |    2.986 |   3.435
# weight_decay=1e-4              :   3.185 |    3.016  |    3.001 |   2.859
# weight_decay=0                 :   3.078 |    2.976  |    2.986 |   2.878
# cosine_sch = 60                :   3.123 |    3.035  |    3.241 |   2.984
# cosine_sch = 120               :   3.136 |    3.077  |    2.963 |   2.903
# cosine_sch = 200               :   3.050 |    2.969  |    2.978 |   2.872
# no_random_shift                :   3.443 |    3.615  |    3.426 |   3.297
# patch=5,feature=48             :   6.248 |    3.113  |    2.966 |   3.433
# patch=5,feature=72             :   3.098 |    6.252  |    6.247 |   4.684
# patch=5,feature=96             :   6.247 |    6.247  |    3.104 |   4.700
# patch=5,feature=48,patience=30,lr=5e-3,200epc :   6.250 |    6.254  |    6.254 |   6.248
# patch=5,feature=72,patience=30,lr=5e-3,200epc :   6.254 |    6.249  |    6.247 |   6.249
# patch=5,feature=96,patience=30,lr=5e-3,200epc :   6.254 |    6.254  |    6.254 |   6.254
# patch=5,feature=48,patience=40,200epc :   2.966 |    3.025  |    3.083 |   2.874
# patch=5,feature=72,patience=40,200epc :   2.913 |    3.295  |    3.061 |   2.889
# patch=5,feature=96,patience=40,200epc :   2.964 |    2.876  |    6.250 |   3.444
# patch=5,feature=48,patience=40,step_lr,200epc :   3.144 |    2.787  |    2.925 |   2.743
# patch=5,feature=72,patience=40,step_lr,200epc :   2.900 |    2.900  |    3.683 |   2.924
# patch=5,feature=96,patience=40,step_lr,200epc :   2.843 |    2.923  |    2.867 |   2.712
# patch=5,feature=48,patience=40,step_lr,120epc :   3.142 |    2.969  |    3.013 |   2.884
# patch=5,feature=72,patience=40,step_lr,120epc :   2.916 |    2.900  |    4.080 |   3.017
# patch=5,feature=96,patience=40,step_lr,120epc :   3.123 |    3.057  |    2.954 |   2.878
# T1NL, p5, f24, d=(2,2,2,2)     :   3.031 |    2.881  |    3.029 |   2.815
# T1NL, p5, f48, d=(2,2,2,2)     :   2.888 |    2.868  |    3.006 |   2.769
# T1NL, p5, f24, d=(2,2,2)       :   2.846 |    2.859  |    2.984 |   2.757
# T1NL, p5, f24, d=(2,2,2)       :   2.902 |    2.928  |    3.045 |   2.791
# FA, p5, f24, d=(2,2,2,2)       :   3.200 |    3.236  |    3.290 |   3.072
# FA, p5, f48, d=(2,2,2,2)       :   3.389 |    3.319  |    3.444 |   3.113
# FA, p5, f24, d=(2,2,2)         :   3.250 |    3.278  |    3.313 |   3.153
# FA, p5, f48, d=(2,2,2)         :   3.138 |    3.227  |    3.405 |   3.076
# TBSS FA, p5, f24, d=(2,2,2,2)  :   3.656 |    3.513  |    3.552 |   3.475
# TBSS FA, p5, f48, d=(2,2,2,2)  :   3.596 |    3.497  |    3.601 |   3.474
# TBSS FA, p5, f24, d=(2,2,2)    :   3.577 |    3.558  |    3.597 |   3.500
# TBSS FA, p5, f48, d=(2,2,2)    :   3.600 |    3.587  |    3.588 |   3.506
# rsfMRI, p5, f24, d=(2,2,2,2)   :   5.384 |    5.482  |    5.541 |   5.401
# rsfMRI, p5, f48, d=(2,2,2,2)   :   5.528 |    5.608  |    5.457 |   5.395
# rsfMRI, p5, f24, d=(2,2,2)     :   5.491 |    5.372  |    5.353 |   5.317
# rsfMRI, p5, f48, d=(2,2,2)     :   5.352 |    5.410  |    5.461 |   5.305
# tracts, p5, f24, d=(2,2,2,2)   :   3.940 |    3.897  |    3.975 |   3.712
# tracts, p5, f48, d=(2,2,2,2)   :   3.851 |    3.990  |    3.825 |   3.683
# tracts, p5, f24, d=(2,2,2)     :   3.845 |    3.725  |    3.788 |   3.629
# tracts, p5, f48, d=(2,2,2)     :   3.732 |    3.726  |    3.762 |   3.569

# %%
# Modality                : MEAN (MAE)      |  MEAN DECONF    
# -----------------------------------------------------------------------------------------------
# InputFusion             :  2.633 ± 0.063  |   2.906 ± 0.071 
# InputFusion_Filter      :  2.829 ± 0.069  |   3.267 ± 0.077 
# LayerFusion9600         :  2.794 ± 0.063  |   3.087 ± 0.073


mae_weighting = 37.137671232876755 # for female subjects
# # mae_weighting = 36.28150684931529 # for male subjects


print("{:50} : {:8}  |  {:8}   |  {:8}   |  {:8} ".format('Modality', 'MAE', "RMSE", 
                                                            "CORR (R)", "MAE weighted"))
print('-----------------------------------------------------------------------------------------------')

for idx in range(len(dfs)):
    print("{:50} :  {:8.3f}  |   {:8.3f}  |   {:8.3f}   |   {:8.3f} ".format(
        names[idx],
        np.abs(dfs[idx].mean_age_delta).mean(), 
#         np.sqrt(np.square(np.subtract(dfs[idx].target_age, dfs[idx].mean_output_age)).mean()),
        np.abs(dfs[idx].age_delta_decon).mean(),
        pearsonr(dfs[idx].target_age, dfs[idx].mean_output_age)[0],
        np.abs(dfs[idx].mean_age_delta).mean() / mae_weighting,
    )
         )
# Out:
# Modality                                           : MAE       |  RMSE       |  CORR (R)   |  MAE weighted
# -----------------------------------------------------------------------------------------------
# 3k_baseline                                        :     2.828  |      3.225  |      0.878   |      0.076
# depth=(1,1,1,1)                                    :     2.818  |      3.168  |      0.880   |      0.076
# heads=(2,4,8,16),b=4                               :     2.901  |      3.294  |      0.874   |      0.078
# feature_size=3                                     :     2.829  |      3.214  |      0.878   |      0.076
# feature_size=6                                     :     2.887  |      3.237  |      0.875   |      0.078
# feature_size=12                                    :     2.842  |      3.230  |      0.878   |      0.077
# patch_size=3                                       :     2.938  |      3.361  |      0.871   |      0.079
# patch_size=4                                       :     2.916  |      3.341  |      0.870   |      0.079
# patch_size=5                                       :     2.847  |      3.213  |      0.879   |      0.077
# warmup=0                                           :    63.420  |   1758.911  |      0.003   |      1.708
# warmup=8                                           :     2.830  |      3.195  |      0.879   |      0.076
# warmup=12                                          :     2.866  |      3.250  |      0.877   |      0.077
# weight_decay=1e-2                                  :     2.891  |      3.267  |      0.876   |      0.078
# weight_decay=1e-3                                  :     3.435  |      3.291  |      0.874   |      0.092
# weight_decay=1e-4                                  :     2.859  |      3.171  |      0.880   |      0.077
# weight_decay=0                                     :     2.878  |      3.276  |      0.875   |      0.077
# cosine_sch = 60                                    :     2.984  |      3.422  |      0.864   |      0.080
# cosine_sch = 120                                   :     2.903  |      3.300  |      0.872   |      0.078
# cosine_sch = 200                                   :     2.872  |      3.244  |      0.877   |      0.077
# no_random_shift                                    :     3.297  |      3.974  |      0.832   |      0.089
# patch=5,feature=48                                 :     3.433  |      3.295  |      0.874   |      0.092
# patch=5,feature=72                                 :     4.684  |      3.505  |      0.860   |      0.126
# patch=5,feature=96                                 :     4.700  |      3.642  |      0.854   |      0.127
# patch=5,feature=48,patience=30,lr=5e-3,200epc      :     6.248  |     60.700  |        nan   |      0.168
# patch=5,feature=72,patience=30,lr=5e-3,200epc      :     6.249  |     64.008  |      0.094   |      0.168
# patch=5,feature=96,patience=30,lr=5e-3,200epc      :     6.254  |     63.421  |        nan   |      0.168
# patch=5,feature=48,patience=40,200epc              :     2.874  |      3.252  |      0.876   |      0.077
# patch=5,feature=72,patience=40,200epc              :     2.889  |      3.252  |      0.876   |      0.078
# patch=5,feature=96,patience=40,200epc              :     3.444  |      3.117  |      0.882   |      0.093
# patch=5,feature=48,patience=40,step_lr,200epc      :     2.743  |      3.079  |      0.885   |      0.074
# patch=5,feature=72,patience=40,step_lr,200epc      :     2.924  |      3.257  |      0.876   |      0.079
# patch=5,feature=96,patience=40,step_lr,200epc      :     2.712  |      3.057  |      0.888   |      0.073
# patch=5,feature=48,patience=40,step_lr,120epc      :     2.884  |      3.253  |      0.875   |      0.078
# patch=5,feature=72,patience=40,step_lr,120epc      :     3.017  |      3.398  |      0.869   |      0.081
# patch=5,feature=96,patience=40,step_lr,120epc      :     2.878  |      3.280  |      0.874   |      0.077
# T1NL, p5, f24, d=(2,2,2,2)                         :     2.815  |      3.180  |      0.881   |      0.076
# T1NL, p5, f48, d=(2,2,2,2)                         :     2.769  |      3.056  |      0.886   |      0.075
# T1NL, p5, f24, d=(2,2,2)                           :     2.757  |      3.134  |      0.883   |      0.074
# T1NL, p5, f24, d=(2,2,2)                           :     2.791  |      3.130  |      0.882   |      0.075
# FA, p5, f24, d=(2,2,2,2)                           :     3.072  |      3.600  |      0.854   |      0.083
# FA, p5, f48, d=(2,2,2,2)                           :     3.113  |      3.678  |      0.849   |      0.084
# FA, p5, f24, d=(2,2,2)                             :     3.153  |      3.740  |      0.846   |      0.085
# FA, p5, f48, d=(2,2,2)                             :     3.076  |      3.635  |      0.853   |      0.083
# TBSS FA, p5, f24, d=(2,2,2,2)                      :     3.475  |      4.323  |      0.810   |      0.094
# TBSS FA, p5, f48, d=(2,2,2,2)                      :     3.474  |      4.300  |      0.810   |      0.094
# TBSS FA, p5, f24, d=(2,2,2)                        :     3.500  |      4.274  |      0.812   |      0.094
# TBSS FA, p5, f48, d=(2,2,2)                        :     3.506  |      4.367  |      0.806   |      0.094
# rsfMRI, p5, f24, d=(2,2,2,2)                       :     5.401  |     11.076  |      0.474   |      0.145
# rsfMRI, p5, f48, d=(2,2,2,2)                       :     5.395  |     10.825  |      0.480   |      0.145
# rsfMRI, p5, f24, d=(2,2,2)                         :     5.317  |     10.708  |      0.484   |      0.143
# rsfMRI, p5, f48, d=(2,2,2)                         :     5.305  |     10.300  |      0.502   |      0.143
# tracts, p5, f24, d=(2,2,2,2)                       :     3.712  |      4.758  |      0.781   |      0.100
# tracts, p5, f48, d=(2,2,2,2)                       :     3.683  |      4.611  |      0.792   |      0.099
# tracts, p5, f24, d=(2,2,2)                         :     3.629  |      4.506  |      0.795   |      0.098
# tracts, p5, f48, d=(2,2,2)                         :     3.569  |      4.426  |      0.802   |      0.096

# %%
maes=[]
prs = []
for idx in range(len(dfs)):
    mae = np.abs(dfs[idx].mean_age_delta).mean()
    maes.append(mae)
    pr = pearsonr(dfs[idx].target_age, dfs[idx].mean_output_age)[0]
    prs.append(pr)
    
print(pearsonr(maes, prs)[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 9>()
#       6     pr = pearsonr(dfs[idx].target_age, dfs[idx].mean_output_age)[0]
#       7     prs.append(pr)
# ----> 9 print(pearsonr(maes, prs)[0])
#
# File ~/opt/anaconda3/envs/SwinAgeMapper/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4455, in pearsonr(x, y, alternative)
#    4451 # Unlike np.linalg.norm or the expression sqrt((xm*xm).sum()),
#    4452 # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    4453 # [-5e210, 5e210, 3e200, -3e200]
#    4454 normxm = linalg.norm(xm)
# -> 4455 normym = linalg.norm(ym)
#    4457 threshold = 1e-13
#    4458 if normxm < threshold*abs(xmean) or normym < threshold*abs(ymean):
#    4459     # If all the values in x (likewise y) are very close to the mean,
#    4460     # the loss of precision that occurs in the subtraction xm = x - xmean
#    4461     # might result in large errors in r.
#
# File ~/opt/anaconda3/envs/SwinAgeMapper/lib/python3.10/site-packages/scipy/linalg/_misc.py:145, in norm(a, ord, axis, keepdims, check_finite)
#     143 # Differs from numpy only in non-finite handling and the use of blas.
#     144 if check_finite:
# --> 145     a = np.asarray_chkfinite(a)
#     146 else:
#     147     a = np.asarray(a)
#
# File ~/opt/anaconda3/envs/SwinAgeMapper/lib/python3.10/site-packages/numpy/lib/function_base.py:627, in asarray_chkfinite(a, dtype, order)
#     625 a = asarray(a, dtype=dtype, order=order)
#     626 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 627     raise ValueError(
#     628         "array must not contain infs or NaNs")
#     629 return a
#
# ValueError: array must not contain infs or NaNs

# %%
print("{:20} : {:7}  |  {:7}  |  {:7} ".format('Modality', 'MAE (DECON)', "RMSE (DECON)", "PR (DECON)"))
print('-----------------------------------------------------------------------------------------------')

for idx in range(len(dfs)):
    print("{:20} :  {:10.3f}  |   {:10.3f}  |   {:7.3f} ".format(
        names[idx],
        np.abs(dfs[idx].age_delta_decon).mean(),
        np.sqrt(np.square(np.subtract(dfs[idx].target_age, dfs[idx].output_age_decon)).mean()), 
        pearsonr(dfs[idx].target_age, dfs[idx].output_age_decon)[0],
    )
         )
# Out:
# Modality             : MAE (DECON)  |  RMSE (DECON)  |  PR (DECON)
# -----------------------------------------------------------------------------------------------
# 3k_baseline          :       3.225  |        4.057  |     0.878
# depth=(1,1,1,1)      :       3.168  |        4.026  |     0.880
# heads=(2,4,8,16),b=4 :       3.294  |        4.148  |     0.874
# feature_size=3       :       3.214  |        4.058  |     0.878
# feature_size=6       :       3.237  |        4.108  |     0.875
# feature_size=12      :       3.230  |        4.055  |     0.878
# patch_size=3         :       3.361  |        4.208  |     0.871
# patch_size=4         :       3.341  |        4.226  |     0.870
# patch_size=5         :       3.213  |        4.041  |     0.879
# warmup=0             :    1758.911  |     2237.626  |     0.003
# warmup=8             :       3.195  |        4.036  |     0.879
# warmup=12            :       3.250  |        4.072  |     0.877
# weight_decay=1e-2    :       3.267  |        4.102  |     0.876
# weight_decay=1e-3    :       3.291  |        4.142  |     0.874
# weight_decay=1e-4    :       3.171  |        4.016  |     0.880
# weight_decay=0       :       3.276  |        4.126  |     0.875
# cosine_sch = 60      :       3.422  |        4.340  |     0.864
# cosine_sch = 120     :       3.300  |        4.172  |     0.872
# cosine_sch = 200     :       3.244  |        4.075  |     0.877
# no_random_shift      :       3.974  |        4.968  |     0.832

# %% [markdown]
# # Saving Dataframe for Later Use

# %%
d = {'modality':names, 'dataframe':dfs}
df = pd.DataFrame(data=d)

# %%
df['dataframe'].iloc[0]
# Out:
#      Unnamed: 0  target_age  output_age_1  age_delta_1      loss_1  \
# 0      24642634   68.817620     71.761314     2.943695    8.665340
# 1      25438579   54.541897     53.974083    -0.567814    0.322413
# 2      21026392   67.284820     63.286260    -3.998562   15.988497
# 3      22526044   67.492805     68.328830     0.836021    0.698932
# 4      25008425   53.802400     65.822860    12.020462  144.491500
# ..          ...         ...           ...          ...         ...
# 994    22396579   53.442810     53.374626    -0.068184    0.004649
# 995    21351411   52.529110     53.400100     0.870991    0.758625
# 996    21230487   53.252050     54.929770     1.677723    2.814754
# 997    22579199   64.787560     65.337270     0.549713    0.302185
# 998    24735119   70.165985     65.012070    -5.153915   26.562843
#
#      output_age_2  age_delta_2     loss_2  output_age_3  age_delta_3  \
# 0       68.871870     0.054253   0.002943     70.051500     1.233879
# 1       55.331017     0.789120   0.622710     55.658980     1.117085
# 2       61.453705    -5.831116  34.001910     62.329536    -4.955284
# 3       66.923065    -0.569740   0.324604     67.739910     0.247101
# 4       62.392452     8.590054  73.789020     63.143740     9.341343
# ..            ...          ...        ...           ...          ...
# 994     52.321102    -1.121708   1.258229     53.010162    -0.432648
# 995     54.592310     2.063202   4.256802     51.478737    -1.050373
# 996     56.152126     2.900078   8.410451     54.943650     1.691601
# 997     63.529640    -1.257919   1.582361     65.086170     0.298607
# 998     64.298874    -5.867111  34.422993     66.753845    -3.412140
#
#         loss_3  mean_output_age  mean_age_delta  output_age_decon  \
# 0     1.522458        70.228228        1.410608         72.444804
# 1     1.247878        54.988027        0.446130         52.637406
# 2    24.554840        62.356500       -4.928320         62.214070
# 3     0.061059        67.663935        0.171130         69.112041
# 4    87.260690        63.786351        9.983951         64.072419
# ..         ...              ...             ...               ...
# 994   0.187184        52.901963       -0.540847         49.926189
# 995   1.103284        53.157049        0.627939         50.257719
# 996   2.861513        55.341849        2.089799         53.097261
# 997   0.089166        64.651027       -0.136533         65.196222
# 998  11.642698        65.354930       -4.811055         66.111071
#
#      age_delta_decon
# 0           3.627184
# 1          -1.904491
# 2          -5.070750
# 3           1.619236
# 4          10.270019
# ..               ...
# 994        -3.516621
# 995        -2.271391
# 996        -0.154789
# 997         0.408662
# 998        -4.054914
#
# [999 rows x 15 columns]

# %%
df
# Out:
#                                          modality  \
# 0                                     3k_baseline
# 1                                 depth=(1,1,1,1)
# 2                            heads=(2,4,8,16),b=4
# 3                                  feature_size=3
# 4                                  feature_size=6
# 5                                 feature_size=12
# 6                                    patch_size=3
# 7                                    patch_size=4
# 8                                    patch_size=5
# 9                                        warmup=0
# 10                                       warmup=8
# 11                                      warmup=12
# 12                              weight_decay=1e-2
# 13                              weight_decay=1e-3
# 14                              weight_decay=1e-4
# 15                                 weight_decay=0
# 16                                cosine_sch = 60
# 17                               cosine_sch = 120
# 18                               cosine_sch = 200
# 19                                no_random_shift
# 20                             patch=5,feature=48
# 21                             patch=5,feature=72
# 22                             patch=5,feature=96
# 23  patch=5,feature=48,patience=30,lr=5e-3,200epc
# 24  patch=5,feature=72,patience=30,lr=5e-3,200epc
# 25  patch=5,feature=96,patience=30,lr=5e-3,200epc
# 26          patch=5,feature=48,patience=40,200epc
# 27          patch=5,feature=72,patience=40,200epc
# 28          patch=5,feature=96,patience=40,200epc
# 29  patch=5,feature=48,patience=40,step_lr,200epc
# 30  patch=5,feature=72,patience=40,step_lr,200epc
# 31  patch=5,feature=96,patience=40,step_lr,200epc
#
#                                             dataframe
# 0        Unnamed: 0  target_age  output_age_1  age...
# 1        Unnamed: 0  target_age  output_age_1  age...
# 2        Unnamed: 0  target_age  output_age_1  age...
# 3        Unnamed: 0  target_age  output_age_1  age...
# 4        Unnamed: 0  target_age  output_age_1  age...
# 5        Unnamed: 0  target_age  output_age_1  age...
# 6        Unnamed: 0  target_age  output_age_1  age...
# 7        Unnamed: 0  target_age  output_age_1  age...
# 8        Unnamed: 0  target_age  output_age_1  age...
# 9        Unnamed: 0  target_age  output_age_1  age...
# 10       Unnamed: 0  target_age  output_age_1  age...
# 11       Unnamed: 0  target_age  output_age_1  age...
# 12       Unnamed: 0  target_age  output_age_1  age...
# 13       Unnamed: 0  target_age  output_age_1  age...
# 14       Unnamed: 0  target_age  output_age_1  age...
# 15       Unnamed: 0  target_age  output_age_1  age...
# 16       Unnamed: 0  target_age  output_age_1  age...
# 17       Unnamed: 0  target_age  output_age_1  age...
# 18       Unnamed: 0  target_age  output_age_1  age...
# 19       Unnamed: 0  target_age  output_age_1  age...
# 20       Unnamed: 0  target_age  output_age_1  age...
# 21       Unnamed: 0  target_age  output_age_1  age...
# 22       Unnamed: 0  target_age  output_age_1  age...
# 23       Unnamed: 0  target_age  output_age_1  age...
# 24       Unnamed: 0  target_age  output_age_1  age...
# 25       Unnamed: 0  target_age  output_age_1  age...
# 26       Unnamed: 0  target_age  output_age_1  age...
# 27       Unnamed: 0  target_age  output_age_1  age...
# 28       Unnamed: 0  target_age  output_age_1  age...
# 29       Unnamed: 0  target_age  output_age_1  age...
# 30       Unnamed: 0  target_age  output_age_1  age...
# 31       Unnamed: 0  target_age  output_age_1  age...

# %%
type(df.dataframe.iloc[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[15].dataframe
# Out:
#      Unnamed: 0  target_age  output_age_1  age_delta_1     loss_1  \
# 0      24642634   68.817620     70.556870     1.739250   3.024991
# 1      25438579   54.541897     58.433243     3.891346  15.142573
# 2      21026392   67.284820     62.173332    -5.111488  26.127314
# 3      22526044   67.492805     68.082670     0.589867   0.347943
# 4      25008425   53.802400     61.704834     7.902435  62.448483
# ..          ...         ...           ...          ...        ...
# 994    22396579   53.442810     53.910637     0.467827   0.218862
# 995    21351411   52.529110     52.199177    -0.329933   0.108856
# 996    21230487   53.252050     57.350590     4.098541  16.798040
# 997    22579199   64.787560     64.232666    -0.554894   0.307907
# 998    24735119   70.165985     69.341640    -0.824348   0.679550
#
#      output_age_2  age_delta_2     loss_2  output_age_3  age_delta_3  \
# 0       70.650300     1.832680   3.358715     69.216820     0.399200
# 1       55.888706     1.346809   1.813896     56.256252     1.714355
# 2       61.572254    -5.712566  32.633415     61.430622    -5.854198
# 3       68.300110     0.807304   0.651740     65.207900    -2.284905
# 4       61.479145     7.676746  58.932434     64.446150    10.643753
# ..            ...          ...        ...           ...          ...
# 994     53.661915     0.219105   0.048007     55.336640     1.893829
# 995     52.825070     0.295959   0.087592     53.102333     0.573223
# 996     56.105930     2.853882   8.144642     55.273760     2.021713
# 997     62.525090    -2.262470   5.118772     62.901756    -1.885803
# 998     65.222990    -4.942993  24.433182     67.290620    -2.875366
#
#          loss_3  mean_output_age  mean_age_delta  output_age_decon  \
# 0      0.159361        70.141330        1.323710         72.174465
# 1      2.939015        56.859400        2.317503         55.043345
# 2     34.271640        61.725403       -5.559417         61.319547
# 3      5.220789        67.196893       -0.295912         68.376711
# 4    113.289480        62.543376        8.740976         62.374575
# ..          ...              ...             ...               ...
# 994    3.586590        54.303064        0.860254         51.746166
# 995    0.328585        52.708860        0.179750         49.689951
# 996    4.087325        56.243427        2.991377         54.248858
# 997    3.556254        63.219837       -1.567723         63.247078
# 998    8.267731        67.285083       -2.880902         68.490459
#
#      age_delta_decon
# 0           3.356845
# 1           0.501448
# 2          -5.965273
# 3           0.883906
# 4           8.572175
# ..               ...
# 994        -1.696644
# 995        -2.839159
# 996         0.996808
# 997        -1.540482
# 998        -1.675526
#
# [999 rows x 15 columns]

# %%
df.iloc[0].modality
# Out:
# '3k_baseline'

# %%
type(df.iloc[0].dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_pickle('female_test_prototype_repeat.pkl', protocol = 4)

# %%
# df2 = pd.read_pickle('female_test.pkl')

# %%
# df2

# %%
# df2.iloc[0].dataframe

# %%
# df2.iloc[0].modality

# %%
# type(df2.iloc[0].dataframe)

# %% [markdown]
# # BarPlots

# %%
# df_test = {}
# for idx in range(len(df)):
#     name = df.iloc[idx].modality
#     data = df.iloc[idx].dataframe.mean_output_age.to_list()
#     df_test[name] = data
    
# df_test = pd.DataFrame.from_dict(df_test)

# array = np.array(df_test)

# fig = plt.figure(figsize=(16, 7.2))
# plt.boxplot(array);
# plt.xticks(np.arange(1, array.shape[1]+1), df_test.columns.to_list(), rotation=90);

# plt.xlabel("Modalities")
# plt.ylabel("Predicted Age Distributions")
# plt.axvline(x=7.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=32.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=38.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=39.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=48.5, color='g', linestyle='dotted', alpha=0.5);

# %%
# df_test = {}
# for idx in range(len(df)):
#     name = df.iloc[idx].modality
#     data = df.iloc[idx].dataframe.mean_age_delta.to_list()
#     df_test[name] = data
    
# df_test = pd.DataFrame.from_dict(df_test)

# array = np.array(df_test)

# fig = plt.figure(figsize=(16, 7.2))
# plt.boxplot(array);
# plt.xticks(np.arange(1, array.shape[1]+1), df_test.columns.to_list(), rotation=90);

# plt.xlabel("Modalities")
# plt.ylabel("Predicted Age Delta Distributions")
# plt.axvline(x=7.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=32.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=38.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=39.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=48.5, color='g', linestyle='dotted', alpha=0.5);

# %%
# df_test = {}
# for idx in range(len(df)):
#     name = df.iloc[idx].modality
#     data = df.iloc[idx].dataframe.output_age_decon.to_list()
#     df_test[name] = data
    
# df_test = pd.DataFrame.from_dict(df_test)

# array = np.array(df_test)

# fig = plt.figure(figsize=(16, 7.2))
# plt.boxplot(array);
# plt.xticks(np.arange(1, array.shape[1]+1), df_test.columns.to_list(), rotation=90);

# plt.xlabel("Modalities")
# plt.ylabel("Predicted Debiased Age Distributions")
# plt.axvline(x=7.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=32.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=38.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=39.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=48.5, color='g', linestyle='dotted', alpha=0.5);

# %%
# df_test = {}
# for idx in range(len(df)):
#     name = df.iloc[idx].modality
#     data = df.iloc[idx].dataframe.age_delta_decon.to_list()
#     df_test[name] = data
    
# df_test = pd.DataFrame.from_dict(df_test)

# array = np.array(df_test)

# fig = plt.figure(figsize=(16, 7.2))
# plt.boxplot(array);
# plt.xticks(np.arange(1, array.shape[1]+1), df_test.columns.to_list(), rotation=90);

# plt.xlabel("Modalities")
# plt.ylabel("Predicted Debiased Age Deltas Distributions")
# plt.axvline(x=7.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=32.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=38.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=39.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=48.5, color='g', linestyle='dotted', alpha=0.5);

# %%
# df_test = {}
# for idx in range(len(df)):
#     name = df.iloc[idx].modality
#     data = df.iloc[idx].dataframe.age_delta_decon.to_list()
#     df_test[name] = data
    
# df_test = pd.DataFrame.from_dict(df_test)

# array = np.abs(np.array(df_test))

# fig = plt.figure(figsize=(16, 7.2))
# plt.boxplot(array);
# plt.xticks(np.arange(1, array.shape[1]+1), df_test.columns.to_list(), rotation=90);

# plt.xlabel("Modalities")
# plt.ylabel("Predicted Absolute Debiased Age Deltas Distributions")
# plt.axvline(x=7.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=32.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=38.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=39.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=48.5, color='g', linestyle='dotted', alpha=0.5);

# %%
# df_test = {}
# for idx in range(len(df)):
#     name = df.iloc[idx].modality
#     data = df.iloc[idx].dataframe.mean_age_delta.to_list()
#     df_test[name] = data
    
# df_test = pd.DataFrame.from_dict(df_test)

# array = np.array(df_test)

# fig = plt.figure(figsize=(16, 7.2))
# # plt.scatter(np.arange(1, len(array), 1), array);
# plt.scatter(np.arange(1, array.shape[1]+1), abs(array).mean(axis=0))
# plt.xticks(np.arange(1, array.shape[1]+1), df_test.columns.to_list(), rotation=90);

# plt.xlabel("Modalities")
# plt.ylabel("MAE")
# plt.axvline(x=7.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=32.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=38.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=39.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axvline(x=48.5, color='g', linestyle='dotted', alpha=0.5);
# plt.axhline(y=6.253, color='r', linestyle='dashed')

# %% [markdown]
# # Test what happens if debiasing before deconfounding

# %%
# dfs[0]

# %%
# for idx in range(len(dfs)):
#     dfs[idx]['output_age_decon_1'] = age_debiasing(dfs[idx].output_age_1, dfs[idx].target_age)
#     dfs[idx]['output_age_decon_2'] = age_debiasing(dfs[idx].output_age_2, dfs[idx].target_age) 
#     dfs[idx]['output_age_decon_3'] = age_debiasing(dfs[idx].output_age_3, dfs[idx].target_age) 
#     dfs[idx]['mean_output_age_decon'] = dfs[idx][['output_age_decon_1', 'output_age_decon_2', 'output_age_decon_3']].mean(axis=1)
#     dfs[idx]['mean_age_delta_decon'] = dfs[idx]['mean_output_age_decon'] - dfs[idx]['target_age']

# %%
# dfs[0]

# %%
# print("{:13} : {:14}  |  {:14}  |  {:13}  |   {:13}  |  {:}  |  {:} ".format('Modality', 'MAE (DECON)', 'MAE (DECON B)', "MSE (DECON)", "MSE (DECON B)",  "PR (DECON)", "PR (DECON B)"))
# print('-----------------------------------------------------------------------------------------------')

# for idx in range(len(dfs)):
#     print("{:13} :  {:.3f} ± {:.3f}  |   {:.3f} ± {:.3f}   |   {:.3f} ± {:.3f}  |   {:.3f} ± {:.3f}   |   {:.3f}   |   {:.3f} ".format(
#         names[idx],
        
#         np.abs(dfs[idx].age_delta_decon).mean(), np.abs(dfs[idx].age_delta_decon).std()/np.sqrt(len(dfs[idx])),
#         np.abs(dfs[idx].mean_age_delta_decon).mean(), np.abs(dfs[idx].mean_age_delta_decon).std()/np.sqrt(len(dfs[idx])),
        
#         np.square(np.subtract(dfs[idx].target_age, dfs[idx].output_age_decon)).mean(), np.square(np.subtract(dfs[idx].target_age, dfs[idx].output_age_decon)).std()/np.sqrt(len(dfs[idx])),
#         np.square(np.subtract(dfs[idx].target_age, dfs[idx].mean_output_age_decon)).mean(), np.square(np.subtract(dfs[idx].target_age, dfs[idx].mean_output_age_decon)).std()/np.sqrt(len(dfs[idx])),
        
#         pearsonr(dfs[idx].target_age, dfs[idx].output_age_decon)[0],
#         pearsonr(dfs[idx].target_age, dfs[idx].mean_output_age_decon)[0],
#     )
#          )
